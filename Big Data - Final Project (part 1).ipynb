# %% [markdown]
# ### <u>**COMP-548DL**</u>
# ### <u>**Big Data Management and Processing**</u>
# ### <u>**Semester Project**</u>

# %% [markdown]
# ###

# %% [markdown]
# #### <u>**Part 1:**</u>
# #### This notebook contains the code used for uploading the data on Firestore in document format.
# #### A few queries are performed for experimentation, but then we transform the data into a JSON file in order to continue with the main approach.
# #### (Utilizing PySpark, uploading the data on GCS and provisioning a Dataproc cluster for the rest of the analysis)

# %%
import firebase_admin
from firebase_admin import credentials, firestore
from collections import defaultdict
import pandas as pd
import time
import json

# %%
 # %env GOOGLE_APPLICATION_CREDENTIALS=C:\Users\ska_p\OneDrive\Desktop\MSc Data Science\Fall Semester 2024-25\Big Data Management and Processing\Final Project\big-data-final-project-445611-3749e103c9e3.json
# Out:
# env: GOOGLE_APPLICATION_CREDENTIALS=C:\Users\ska_p\OneDrive\Desktop\MSc Data Science\Fall Semester 2024-25\Big Data Management and Processing\Final Project\big-data-final-project-445611-3749e103c9e3.json

# %%
# Initializing Google Firestore
cred = credentials.Certificate("C:/Users/ska_p/OneDrive/Desktop/MSc Data Science/Fall Semester 2024-25/Big Data Management and Processing/Final Project/big-data-final-project-445611-3749e103c9e3.json")
firebase_admin.initialize_app(cred)
db = firestore.client()

# Creating a Firestore collection name
collection_name = "crime_data"

# %%
# Loading our dataset 
file_path = "london_crime.csv"  
data = pd.read_csv(file_path)

# %%
# This is a function for uploading the data in batches
# Calling the function separately will help us tackle any issues in a timely and clean manner
def upload_to_firestore(batch_size=499):
    total_rows = len(data)
    print(f"Uploading {total_rows} rows to Firestore...")

    for start_idx in range(0, total_rows, batch_size):
        batch = db.batch()
        end_idx = min(start_idx + batch_size, total_rows)
        print(f"Uploading rows {start_idx} to {end_idx}...")
        
        # Prepare documents for the batch
        for _, row in data.iloc[start_idx:end_idx].iterrows():
            doc_ref = db.collection(collection_name).document()
            doc_data = {
                "lsoa_code": row["lsoa_code"],
                "borough": row["borough"],
                "major_category": row["major_category"],
                "minor_category": row["minor_category"],
                "value": int(row["value"]),
                "year": int(row["year"]),
                "month": int(row["month"]),
            }
            batch.set(doc_ref, doc_data)

        # Commit the batch
        batch.commit()

    # Just a little reassurance...!    
    print("Data upload complete!")

# %% [markdown]
# #### Now we call the function to finish the upload. It is a very time-consuming process, but it obviously has to be executed only once.

# %%
# Call the function
upload_to_firestore()
# Out:
# Uploading 13490604 rows to Firestore...
# Uploading rows 0 to 499...
# Uploading rows 499 to 998...
# Uploading rows 998 to 1497...
# Uploading rows 1497 to 1996...
# Uploading rows 1996 to 2495...
# Uploading rows 2495 to 2994...
# Uploading rows 2994 to 3493...
# Uploading rows 3493 to 3992...
# Uploading rows 3992 to 4491...
# Uploading rows 4491 to 4990...
# Uploading rows 4990 to 5489...
# Uploading rows 5489 to 5988...
# Uploading rows 5988 to 6487...
# Uploading rows 6487 to 6986...
# Uploading rows 6986 to 7485...
# Uploading rows 7485 to 7984...
# Uploading rows 7984 to 8483...
# Uploading rows 8483 to 8982...
# Uploading rows 8982 to 9481...
# Uploading rows 9481 to 9980...
# Uploading rows 9980 to 10479...
# Uploading rows 10479 to 10978...
# Uploading rows 10978 to 11477...
# Uploading rows 11477 to 11976...
# Uploading rows 11976 to 12475...
# Uploading rows 12475 to 12974...
# Uploading rows 12974 to 13473...
# Uploading rows 13473 to 13972...
# Uploading rows 13972 to 14471...
# Uploading rows 14471 to 14970...
# Uploading rows 14970 to 15469...
# Uploading rows 15469 to 15968...
# Uploading rows 15968 to 16467...
# Uploading rows 16467 to 16966...
# Uploading rows 16966 to 17465...
# Uploading rows 17465 to 17964...
# Uploading rows 17964 to 18463...
# Uploading rows 18463 to 18962...
# Uploading rows 18962 to 19461...
# Uploading rows 19461 to 19960...
# Uploading rows 19960 to 20459...
# Uploading rows 20459 to 20958...
# Uploading rows 20958 to 21457...
# Uploading rows 21457 to 21956...
# Uploading rows 21956 to 22455...
# Uploading rows 22455 to 22954...
# Uploading rows 22954 to 23453...
# Uploading rows 23453 to 23952...
# Uploading rows 23952 to 24451...
# Uploading rows 24451 to 24950...
# Uploading rows 24950 to 25449...
# Uploading rows 25449 to 25948...
# Uploading rows 25948 to 26447...
# Uploading rows 26447 to 26946...
# Uploading rows 26946 to 27445...
# Uploading rows 27445 to 27944...
# Uploading rows 27944 to 28443...
# Uploading rows 28443 to 28942...
# Uploading rows 28942 to 29441...
# Uploading rows 29441 to 29940...
# Uploading rows 29940 to 30439...
# Uploading rows 30439 to 30938...
# Uploading rows 30938 to 31437...
# Uploading rows 31437 to 31936...
# Uploading rows 31936 to 32435...
# Uploading rows 32435 to 32934...
# Uploading rows 32934 to 33433...
# Uploading rows 33433 to 33932...
# Uploading rows 33932 to 34431...
# Uploading rows 34431 to 34930...
# Uploading rows 34930 to 35429...
# Uploading rows 35429 to 35928...
# Uploading rows 35928 to 36427...
# Uploading rows 36427 to 36926...
# Uploading rows 36926 to 37425...
# Uploading rows 37425 to 37924...
# Uploading rows 37924 to 38423...
# Uploading rows 38423 to 38922...
# Uploading rows 38922 to 39421...
# Uploading rows 39421 to 39920...
# Uploading rows 39920 to 40419...
# Uploading rows 40419 to 40918...
# Uploading rows 40918 to 41417...
# Uploading rows 41417 to 41916...
# Uploading rows 41916 to 42415...
# Uploading rows 42415 to 42914...
# Uploading rows 42914 to 43413...
# Uploading rows 43413 to 43912...
# Uploading rows 43912 to 44411...
# Uploading rows 44411 to 44910...
# Uploading rows 44910 to 45409...
# Uploading rows 45409 to 45908...
# Uploading rows 45908 to 46407...
# Uploading rows 46407 to 46906...
# Uploading rows 46906 to 47405...
# Uploading rows 47405 to 47904...
# Uploading rows 47904 to 48403...
# Uploading rows 48403 to 48902...
# Uploading rows 48902 to 49401...
# Uploading rows 49401 to 49900...
# Uploading rows 49900 to 50399...
# Uploading rows 50399 to 50898...
# Uploading rows 50898 to 51397...
# Uploading rows 51397 to 51896...
# Uploading rows 51896 to 52395...
# Uploading rows 52395 to 52894...
# Uploading rows 52894 to 53393...
# Uploading rows 53393 to 53892...
# Uploading rows 53892 to 54391...
# Uploading rows 54391 to 54890...
# Uploading rows 54890 to 55389...
# Uploading rows 55389 to 55888...
# Uploading rows 55888 to 56387...
# Uploading rows 56387 to 56886...
# Uploading rows 56886 to 57385...
# Uploading rows 57385 to 57884...
# Uploading rows 57884 to 58383...
# Uploading rows 58383 to 58882...
# Uploading rows 58882 to 59381...
# Uploading rows 59381 to 59880...
# Uploading rows 59880 to 60379...
# Uploading rows 60379 to 60878...
# Uploading rows 60878 to 61377...
# Uploading rows 61377 to 61876...
# Uploading rows 61876 to 62375...
# Uploading rows 62375 to 62874...
# Uploading rows 62874 to 63373...
# Uploading rows 63373 to 63872...
# Uploading rows 63872 to 64371...
# Uploading rows 64371 to 64870...
# Uploading rows 64870 to 65369...
# Uploading rows 65369 to 65868...
# Uploading rows 65868 to 66367...
# Uploading rows 66367 to 66866...
# Uploading rows 66866 to 67365...
# Uploading rows 67365 to 67864...
# Uploading rows 67864 to 68363...
# Uploading rows 68363 to 68862...
# Uploading rows 68862 to 69361...
# Uploading rows 69361 to 69860...
# Uploading rows 69860 to 70359...
# Uploading rows 70359 to 70858...
# Uploading rows 70858 to 71357...
# Uploading rows 71357 to 71856...
# Uploading rows 71856 to 72355...
# Uploading rows 72355 to 72854...
# Uploading rows 72854 to 73353...
# Uploading rows 73353 to 73852...
# Uploading rows 73852 to 74351...
# Uploading rows 74351 to 74850...
# Uploading rows 74850 to 75349...
# Uploading rows 75349 to 75848...
# Uploading rows 75848 to 76347...
# Uploading rows 76347 to 76846...
# Uploading rows 76846 to 77345...
# Uploading rows 77345 to 77844...
# Uploading rows 77844 to 78343...
# Uploading rows 78343 to 78842...
# Uploading rows 78842 to 79341...
# Uploading rows 79341 to 79840...
# Uploading rows 79840 to 80339...
# Uploading rows 80339 to 80838...
# Uploading rows 80838 to 81337...
# Uploading rows 81337 to 81836...
# Uploading rows 81836 to 82335...
# Uploading rows 82335 to 82834...
# Uploading rows 82834 to 83333...
# Uploading rows 83333 to 83832...
# Uploading rows 83832 to 84331...
# Uploading rows 84331 to 84830...
# Uploading rows 84830 to 85329...
# Uploading rows 85329 to 85828...
# Uploading rows 85828 to 86327...
# Uploading rows 86327 to 86826...
# Uploading rows 86826 to 87325...
# Uploading rows 87325 to 87824...
# Uploading rows 87824 to 88323...
# Uploading rows 88323 to 88822...
# Uploading rows 88822 to 89321...
# Uploading rows 89321 to 89820...
# Uploading rows 89820 to 90319...
# Uploading rows 90319 to 90818...
# Uploading rows 90818 to 91317...
# Uploading rows 91317 to 91816...
# Uploading rows 91816 to 92315...
# Uploading rows 92315 to 92814...
# Uploading rows 92814 to 93313...
# Uploading rows 93313 to 93812...
# Uploading rows 93812 to 94311...
# Uploading rows 94311 to 94810...
# Uploading rows 94810 to 95309...
# Uploading rows 95309 to 95808...
# Uploading rows 95808 to 96307...
# Uploading rows 96307 to 96806...
# Uploading rows 96806 to 97305...
# Uploading rows 97305 to 97804...
# Uploading rows 97804 to 98303...
# Uploading rows 98303 to 98802...
# Uploading rows 98802 to 99301...
# Uploading rows 99301 to 99800...
# Uploading rows 99800 to 100299...
# Uploading rows 100299 to 100798...
# Uploading rows 100798 to 101297...
# Uploading rows 101297 to 101796...
# Uploading rows 101796 to 102295...
# Uploading rows 102295 to 102794...
# Uploading rows 102794 to 103293...
# Uploading rows 103293 to 103792...
# Uploading rows 103792 to 104291...
# Uploading rows 104291 to 104790...
# Uploading rows 104790 to 105289...
# Uploading rows 105289 to 105788...
# Uploading rows 105788 to 106287...
# Uploading rows 106287 to 106786...
# Uploading rows 106786 to 107285...
# Uploading rows 107285 to 107784...
# Uploading rows 107784 to 108283...
# Uploading rows 108283 to 108782...
# Uploading rows 108782 to 109281...
# Uploading rows 109281 to 109780...
# Uploading rows 109780 to 110279...
# Uploading rows 110279 to 110778...
# Uploading rows 110778 to 111277...
# Uploading rows 111277 to 111776...
# Uploading rows 111776 to 112275...
# Uploading rows 112275 to 112774...
# Uploading rows 112774 to 113273...
# Uploading rows 113273 to 113772...
# Uploading rows 113772 to 114271...
# Uploading rows 114271 to 114770...
# Uploading rows 114770 to 115269...
# Uploading rows 115269 to 115768...
# Uploading rows 115768 to 116267...
# Uploading rows 116267 to 116766...
# Uploading rows 116766 to 117265...
# Uploading rows 117265 to 117764...
# Uploading rows 117764 to 118263...
# Uploading rows 118263 to 118762...
# Uploading rows 118762 to 119261...
# Uploading rows 119261 to 119760...
# Uploading rows 119760 to 120259...
# Uploading rows 120259 to 120758...
# Uploading rows 120758 to 121257...
# Uploading rows 121257 to 121756...
# Uploading rows 121756 to 122255...
# Uploading rows 122255 to 122754...
# Uploading rows 122754 to 123253...
# Uploading rows 123253 to 123752...
# Uploading rows 123752 to 124251...
# Uploading rows 124251 to 124750...
# Uploading rows 124750 to 125249...
# Uploading rows 125249 to 125748...
# Uploading rows 125748 to 126247...
# Uploading rows 126247 to 126746...
# Uploading rows 126746 to 127245...
# Uploading rows 127245 to 127744...
# Uploading rows 127744 to 128243...
# Uploading rows 128243 to 128742...
# Uploading rows 128742 to 129241...
# Uploading rows 129241 to 129740...
# Uploading rows 129740 to 130239...
# Uploading rows 130239 to 130738...
# Uploading rows 130738 to 131237...
# Uploading rows 131237 to 131736...
# Uploading rows 131736 to 132235...
# Uploading rows 132235 to 132734...
# Uploading rows 132734 to 133233...
# Uploading rows 133233 to 133732...
# Uploading rows 133732 to 134231...
# Uploading rows 134231 to 134730...
# Uploading rows 134730 to 135229...
# Uploading rows 135229 to 135728...
# Uploading rows 135728 to 136227...
# Uploading rows 136227 to 136726...
# Uploading rows 136726 to 137225...
# Uploading rows 137225 to 137724...
# Uploading rows 137724 to 138223...
# Uploading rows 138223 to 138722...
# Uploading rows 138722 to 139221...
# Uploading rows 139221 to 139720...
# Uploading rows 139720 to 140219...
# Uploading rows 140219 to 140718...
# Uploading rows 140718 to 141217...
# Uploading rows 141217 to 141716...
# Uploading rows 141716 to 142215...
# Uploading rows 142215 to 142714...
# Uploading rows 142714 to 143213...
# Uploading rows 143213 to 143712...
# Uploading rows 143712 to 144211...
# Uploading rows 144211 to 144710...
# Uploading rows 144710 to 145209...
# Uploading rows 145209 to 145708...
# Uploading rows 145708 to 146207...
# Uploading rows 146207 to 146706...
# Uploading rows 146706 to 147205...
# Uploading rows 147205 to 147704...
# Uploading rows 147704 to 148203...
# Uploading rows 148203 to 148702...
# Uploading rows 148702 to 149201...
# Uploading rows 149201 to 149700...
# Uploading rows 149700 to 150199...
# Uploading rows 150199 to 150698...
# Uploading rows 150698 to 151197...
# Uploading rows 151197 to 151696...
# Uploading rows 151696 to 152195...
# Uploading rows 152195 to 152694...
# Uploading rows 152694 to 153193...
# Uploading rows 153193 to 153692...
# Uploading rows 153692 to 154191...
# Uploading rows 154191 to 154690...
# Uploading rows 154690 to 155189...
# Uploading rows 155189 to 155688...
# Uploading rows 155688 to 156187...
# Uploading rows 156187 to 156686...
# Uploading rows 156686 to 157185...
# Uploading rows 157185 to 157684...
# Uploading rows 157684 to 158183...
# Uploading rows 158183 to 158682...
# Uploading rows 158682 to 159181...
# Uploading rows 159181 to 159680...
# Uploading rows 159680 to 160179...
# Uploading rows 160179 to 160678...
# Uploading rows 160678 to 161177...
# Uploading rows 161177 to 161676...
# Uploading rows 161676 to 162175...
# Uploading rows 162175 to 162674...
# Uploading rows 162674 to 163173...
# Uploading rows 163173 to 163672...
# Uploading rows 163672 to 164171...
# Uploading rows 164171 to 164670...
# Uploading rows 164670 to 165169...
# Uploading rows 165169 to 165668...
# Uploading rows 165668 to 166167...
# Uploading rows 166167 to 166666...
# Uploading rows 166666 to 167165...
# Uploading rows 167165 to 167664...
# Uploading rows 167664 to 168163...
# Uploading rows 168163 to 168662...
# Uploading rows 168662 to 169161...
# Uploading rows 169161 to 169660...
# Uploading rows 169660 to 170159...
# Uploading rows 170159 to 170658...
# Uploading rows 170658 to 171157...
# Uploading rows 171157 to 171656...
# Uploading rows 171656 to 172155...
# Uploading rows 172155 to 172654...
# Uploading rows 172654 to 173153...
# Uploading rows 173153 to 173652...
# Uploading rows 173652 to 174151...
# Uploading rows 174151 to 174650...
# Uploading rows 174650 to 175149...
# Uploading rows 175149 to 175648...
# Uploading rows 175648 to 176147...
# Uploading rows 176147 to 176646...
# Uploading rows 176646 to 177145...
# Uploading rows 177145 to 177644...
# Uploading rows 177644 to 178143...
# Uploading rows 178143 to 178642...
# Uploading rows 178642 to 179141...
# Uploading rows 179141 to 179640...
# Uploading rows 179640 to 180139...
# Uploading rows 180139 to 180638...
# Uploading rows 180638 to 181137...
# Uploading rows 181137 to 181636...
# Uploading rows 181636 to 182135...
# Uploading rows 182135 to 182634...
# Uploading rows 182634 to 183133...
# Uploading rows 183133 to 183632...
# Uploading rows 183632 to 184131...
# Uploading rows 184131 to 184630...
# Uploading rows 184630 to 185129...
# Uploading rows 185129 to 185628...
# Uploading rows 185628 to 186127...
# Uploading rows 186127 to 186626...
# Uploading rows 186626 to 187125...
# Uploading rows 187125 to 187624...
# Uploading rows 187624 to 188123...
# Uploading rows 188123 to 188622...
# Uploading rows 188622 to 189121...
# Uploading rows 189121 to 189620...
# Uploading rows 189620 to 190119...
# Uploading rows 190119 to 190618...
# Uploading rows 190618 to 191117...
# Uploading rows 191117 to 191616...
# Uploading rows 191616 to 192115...
# Uploading rows 192115 to 192614...
# Uploading rows 192614 to 193113...
# Uploading rows 193113 to 193612...
# Uploading rows 193612 to 194111...
# Uploading rows 194111 to 194610...
# Uploading rows 194610 to 195109...
# Uploading rows 195109 to 195608...
# Uploading rows 195608 to 196107...
# Uploading rows 196107 to 196606...
# Uploading rows 196606 to 197105...
# Uploading rows 197105 to 197604...
# Uploading rows 197604 to 198103...
# Uploading rows 198103 to 198602...
# Uploading rows 198602 to 199101...
# Uploading rows 199101 to 199600...
# Uploading rows 199600 to 200099...
# Uploading rows 200099 to 200598...
# Uploading rows 200598 to 201097...
# Uploading rows 201097 to 201596...
# Uploading rows 201596 to 202095...
# Uploading rows 202095 to 202594...
# Uploading rows 202594 to 203093...
# Uploading rows 203093 to 203592...
# Uploading rows 203592 to 204091...
# Uploading rows 204091 to 204590...
# Uploading rows 204590 to 205089...
# Uploading rows 205089 to 205588...
# Uploading rows 205588 to 206087...
# Uploading rows 206087 to 206586...
# Uploading rows 206586 to 207085...
# Uploading rows 207085 to 207584...
# Uploading rows 207584 to 208083...
# Uploading rows 208083 to 208582...
# Uploading rows 208582 to 209081...
# Uploading rows 209081 to 209580...
# Uploading rows 209580 to 210079...
# Uploading rows 210079 to 210578...
# Uploading rows 210578 to 211077...
# Uploading rows 211077 to 211576...
# Uploading rows 211576 to 212075...
# Uploading rows 212075 to 212574...
# Uploading rows 212574 to 213073...
# Uploading rows 213073 to 213572...
# Uploading rows 213572 to 214071...
# Uploading rows 214071 to 214570...
# Uploading rows 214570 to 215069...
# Uploading rows 215069 to 215568...
# Uploading rows 215568 to 216067...
# Uploading rows 216067 to 216566...
# Uploading rows 216566 to 217065...
# Uploading rows 217065 to 217564...
# Uploading rows 217564 to 218063...
# Uploading rows 218063 to 218562...
# Uploading rows 218562 to 219061...
# Uploading rows 219061 to 219560...
# Uploading rows 219560 to 220059...
# Uploading rows 220059 to 220558...
# Uploading rows 220558 to 221057...
# Uploading rows 221057 to 221556...
# Uploading rows 221556 to 222055...
# Uploading rows 222055 to 222554...
# Uploading rows 222554 to 223053...
# Uploading rows 223053 to 223552...
# Uploading rows 223552 to 224051...
# Uploading rows 224051 to 224550...
# Uploading rows 224550 to 225049...
# Uploading rows 225049 to 225548...
# Uploading rows 225548 to 226047...
# Uploading rows 226047 to 226546...
# Uploading rows 226546 to 227045...
# Uploading rows 227045 to 227544...
# Uploading rows 227544 to 228043...
# Uploading rows 228043 to 228542...
# Uploading rows 228542 to 229041...
# Uploading rows 229041 to 229540...
# Uploading rows 229540 to 230039...
# Uploading rows 230039 to 230538...
# Uploading rows 230538 to 231037...
# Uploading rows 231037 to 231536...
# Uploading rows 231536 to 232035...
# Uploading rows 232035 to 232534...
# Uploading rows 232534 to 233033...
# Uploading rows 233033 to 233532...
# Uploading rows 233532 to 234031...
# Uploading rows 234031 to 234530...
# Uploading rows 234530 to 235029...
# Uploading rows 235029 to 235528...
# Uploading rows 235528 to 236027...
# Uploading rows 236027 to 236526...
# Uploading rows 236526 to 237025...
# Uploading rows 237025 to 237524...
# Uploading rows 237524 to 238023...
# Uploading rows 238023 to 238522...
# Uploading rows 238522 to 239021...
# Uploading rows 239021 to 239520...
# Uploading rows 239520 to 240019...
# Uploading rows 240019 to 240518...
# Uploading rows 240518 to 241017...
# Uploading rows 241017 to 241516...
# Uploading rows 241516 to 242015...
# Uploading rows 242015 to 242514...
# Uploading rows 242514 to 243013...
# Uploading rows 243013 to 243512...
# Uploading rows 243512 to 244011...
# Uploading rows 244011 to 244510...
# Uploading rows 244510 to 245009...
# Uploading rows 245009 to 245508...
# Uploading rows 245508 to 246007...
# Uploading rows 246007 to 246506...
# Uploading rows 246506 to 247005...
# Uploading rows 247005 to 247504...
# Uploading rows 247504 to 248003...
# Uploading rows 248003 to 248502...
# Uploading rows 248502 to 249001...
# Uploading rows 249001 to 249500...
# Uploading rows 249500 to 249999...
# Uploading rows 249999 to 250498...
# Uploading rows 250498 to 250997...
# Uploading rows 250997 to 251496...
# Uploading rows 251496 to 251995...
# Uploading rows 251995 to 252494...
# Uploading rows 252494 to 252993...
# Uploading rows 252993 to 253492...
# Uploading rows 253492 to 253991...
# Uploading rows 253991 to 254490...
# Uploading rows 254490 to 254989...
# Uploading rows 254989 to 255488...
# Uploading rows 255488 to 255987...
# Uploading rows 255987 to 256486...
# Uploading rows 256486 to 256985...
# Uploading rows 256985 to 257484...
# Uploading rows 257484 to 257983...
# Uploading rows 257983 to 258482...
# Uploading rows 258482 to 258981...
# Uploading rows 258981 to 259480...
# Uploading rows 259480 to 259979...
# Uploading rows 259979 to 260478...
# Uploading rows 260478 to 260977...
# Uploading rows 260977 to 261476...
# Uploading rows 261476 to 261975...
# Uploading rows 261975 to 262474...
# Uploading rows 262474 to 262973...
# Uploading rows 262973 to 263472...
# Uploading rows 263472 to 263971...
# Uploading rows 263971 to 264470...
# Uploading rows 264470 to 264969...
# Uploading rows 264969 to 265468...
# Uploading rows 265468 to 265967...
# Uploading rows 265967 to 266466...
# Uploading rows 266466 to 266965...
# Uploading rows 266965 to 267464...
# Uploading rows 267464 to 267963...
# Uploading rows 267963 to 268462...
# Uploading rows 268462 to 268961...
# Uploading rows 268961 to 269460...
# Uploading rows 269460 to 269959...
# Uploading rows 269959 to 270458...
# Uploading rows 270458 to 270957...
# Uploading rows 270957 to 271456...
# Uploading rows 271456 to 271955...
# Uploading rows 271955 to 272454...
# Uploading rows 272454 to 272953...
# Uploading rows 272953 to 273452...
# Uploading rows 273452 to 273951...
# Uploading rows 273951 to 274450...
# Uploading rows 274450 to 274949...
# Uploading rows 274949 to 275448...
# Uploading rows 275448 to 275947...
# Uploading rows 275947 to 276446...
# Uploading rows 276446 to 276945...
# Uploading rows 276945 to 277444...
# Uploading rows 277444 to 277943...
# Uploading rows 277943 to 278442...
# Uploading rows 278442 to 278941...
# Uploading rows 278941 to 279440...
# Uploading rows 279440 to 279939...
# Uploading rows 279939 to 280438...
# Uploading rows 280438 to 280937...
# Uploading rows 280937 to 281436...
# Uploading rows 281436 to 281935...
# Uploading rows 281935 to 282434...
# Uploading rows 282434 to 282933...
# Uploading rows 282933 to 283432...
# Uploading rows 283432 to 283931...
# Uploading rows 283931 to 284430...
# Uploading rows 284430 to 284929...
# Uploading rows 284929 to 285428...
# Uploading rows 285428 to 285927...
# Uploading rows 285927 to 286426...
# Uploading rows 286426 to 286925...
# Uploading rows 286925 to 287424...
# Uploading rows 287424 to 287923...
# Uploading rows 287923 to 288422...
# Uploading rows 288422 to 288921...
# Uploading rows 288921 to 289420...
# Uploading rows 289420 to 289919...
# Uploading rows 289919 to 290418...
# Uploading rows 290418 to 290917...
# Uploading rows 290917 to 291416...
# Uploading rows 291416 to 291915...
# Uploading rows 291915 to 292414...
# Uploading rows 292414 to 292913...
# Uploading rows 292913 to 293412...
# Uploading rows 293412 to 293911...
# Uploading rows 293911 to 294410...
# Uploading rows 294410 to 294909...
# Uploading rows 294909 to 295408...
# Uploading rows 295408 to 295907...
# Uploading rows 295907 to 296406...
# Uploading rows 296406 to 296905...
# Uploading rows 296905 to 297404...
# Uploading rows 297404 to 297903...
# Uploading rows 297903 to 298402...
# Uploading rows 298402 to 298901...
# Uploading rows 298901 to 299400...
# Uploading rows 299400 to 299899...
# Uploading rows 299899 to 300398...
# Uploading rows 300398 to 300897...
# Uploading rows 300897 to 301396...
# Uploading rows 301396 to 301895...
# Uploading rows 301895 to 302394...
# Uploading rows 302394 to 302893...
# Uploading rows 302893 to 303392...
# Uploading rows 303392 to 303891...
# Uploading rows 303891 to 304390...
# Uploading rows 304390 to 304889...
# Uploading rows 304889 to 305388...
# Uploading rows 305388 to 305887...
# Uploading rows 305887 to 306386...
# Uploading rows 306386 to 306885...
# Uploading rows 306885 to 307384...
# Uploading rows 307384 to 307883...
# Uploading rows 307883 to 308382...
# Uploading rows 308382 to 308881...
# Uploading rows 308881 to 309380...
# Uploading rows 309380 to 309879...
# Uploading rows 309879 to 310378...
# Uploading rows 310378 to 310877...
# Uploading rows 310877 to 311376...
# Uploading rows 311376 to 311875...
# Uploading rows 311875 to 312374...
# Uploading rows 312374 to 312873...
# Uploading rows 312873 to 313372...
# Uploading rows 313372 to 313871...
# Uploading rows 313871 to 314370...
# Uploading rows 314370 to 314869...
# Uploading rows 314869 to 315368...
# Uploading rows 315368 to 315867...
# Uploading rows 315867 to 316366...
# Uploading rows 316366 to 316865...
# Uploading rows 316865 to 317364...
# Uploading rows 317364 to 317863...
# Uploading rows 317863 to 318362...
# Uploading rows 318362 to 318861...
# Uploading rows 318861 to 319360...
# Uploading rows 319360 to 319859...
# Uploading rows 319859 to 320358...
# Uploading rows 320358 to 320857...
# Uploading rows 320857 to 321356...
# Uploading rows 321356 to 321855...
# Uploading rows 321855 to 322354...
# Uploading rows 322354 to 322853...
# Uploading rows 322853 to 323352...
# Uploading rows 323352 to 323851...
# Uploading rows 323851 to 324350...
# Uploading rows 324350 to 324849...
# Uploading rows 324849 to 325348...
# Uploading rows 325348 to 325847...
# Uploading rows 325847 to 326346...
# Uploading rows 326346 to 326845...
# Uploading rows 326845 to 327344...
# Uploading rows 327344 to 327843...
# Uploading rows 327843 to 328342...
# Uploading rows 328342 to 328841...
# Uploading rows 328841 to 329340...
# Uploading rows 329340 to 329839...
# Uploading rows 329839 to 330338...
# Uploading rows 330338 to 330837...
# Uploading rows 330837 to 331336...
# Uploading rows 331336 to 331835...
# Uploading rows 331835 to 332334...
# Uploading rows 332334 to 332833...
# Uploading rows 332833 to 333332...
# Uploading rows 333332 to 333831...
# Uploading rows 333831 to 334330...
# Uploading rows 334330 to 334829...
# Uploading rows 334829 to 335328...
# Uploading rows 335328 to 335827...
# Uploading rows 335827 to 336326...
# Uploading rows 336326 to 336825...
# Uploading rows 336825 to 337324...
# Uploading rows 337324 to 337823...
# Uploading rows 337823 to 338322...
# Uploading rows 338322 to 338821...
# Uploading rows 338821 to 339320...
# Uploading rows 339320 to 339819...
# Uploading rows 339819 to 340318...
# Uploading rows 340318 to 340817...
# Uploading rows 340817 to 341316...
# Uploading rows 341316 to 341815...
# Uploading rows 341815 to 342314...
# Uploading rows 342314 to 342813...
# Uploading rows 342813 to 343312...
# Uploading rows 343312 to 343811...
# Uploading rows 343811 to 344310...
# Uploading rows 344310 to 344809...
# Uploading rows 344809 to 345308...
# Uploading rows 345308 to 345807...
# Uploading rows 345807 to 346306...
# Uploading rows 346306 to 346805...
# Uploading rows 346805 to 347304...
# Uploading rows 347304 to 347803...
# Uploading rows 347803 to 348302...
# Uploading rows 348302 to 348801...
# Uploading rows 348801 to 349300...
# Uploading rows 349300 to 349799...
# Uploading rows 349799 to 350298...
# Uploading rows 350298 to 350797...
# Uploading rows 350797 to 351296...
# Uploading rows 351296 to 351795...
# Uploading rows 351795 to 352294...
# Uploading rows 352294 to 352793...
# Uploading rows 352793 to 353292...
# Uploading rows 353292 to 353791...
# Uploading rows 353791 to 354290...
# Uploading rows 354290 to 354789...
# Uploading rows 354789 to 355288...
# Uploading rows 355288 to 355787...
# Uploading rows 355787 to 356286...
# Uploading rows 356286 to 356785...
# Uploading rows 356785 to 357284...
# Uploading rows 357284 to 357783...
# Uploading rows 357783 to 358282...
# Uploading rows 358282 to 358781...
# Uploading rows 358781 to 359280...
# Uploading rows 359280 to 359779...
# Uploading rows 359779 to 360278...
# Uploading rows 360278 to 360777...
# Uploading rows 360777 to 361276...
# Uploading rows 361276 to 361775...
# Uploading rows 361775 to 362274...
# Uploading rows 362274 to 362773...
# Uploading rows 362773 to 363272...
# Uploading rows 363272 to 363771...
# Uploading rows 363771 to 364270...
# Uploading rows 364270 to 364769...
# Uploading rows 364769 to 365268...
# Uploading rows 365268 to 365767...
# Uploading rows 365767 to 366266...
# Uploading rows 366266 to 366765...
# Uploading rows 366765 to 367264...
# Uploading rows 367264 to 367763...
# Uploading rows 367763 to 368262...
# Uploading rows 368262 to 368761...
# Uploading rows 368761 to 369260...
# Uploading rows 369260 to 369759...
# Uploading rows 369759 to 370258...
# Uploading rows 370258 to 370757...
# Uploading rows 370757 to 371256...
# Uploading rows 371256 to 371755...
# Uploading rows 371755 to 372254...
# Uploading rows 372254 to 372753...
# Uploading rows 372753 to 373252...
# Uploading rows 373252 to 373751...
# Uploading rows 373751 to 374250...
# Uploading rows 374250 to 374749...
# Uploading rows 374749 to 375248...
# Uploading rows 375248 to 375747...
# Uploading rows 375747 to 376246...
# Uploading rows 376246 to 376745...
# Uploading rows 376745 to 377244...
# Uploading rows 377244 to 377743...
# Uploading rows 377743 to 378242...
# Uploading rows 378242 to 378741...
# Uploading rows 378741 to 379240...
# Uploading rows 379240 to 379739...
# Uploading rows 379739 to 380238...
# Uploading rows 380238 to 380737...
# Uploading rows 380737 to 381236...
# Uploading rows 381236 to 381735...
# Uploading rows 381735 to 382234...
# Uploading rows 382234 to 382733...
# Uploading rows 382733 to 383232...
# Uploading rows 383232 to 383731...
# Uploading rows 383731 to 384230...
# Uploading rows 384230 to 384729...
# Uploading rows 384729 to 385228...
# Uploading rows 385228 to 385727...
# Uploading rows 385727 to 386226...
# Uploading rows 386226 to 386725...
# Uploading rows 386725 to 387224...
# Uploading rows 387224 to 387723...
# Uploading rows 387723 to 388222...
# Uploading rows 388222 to 388721...
# Uploading rows 388721 to 389220...
# Uploading rows 389220 to 389719...
# Uploading rows 389719 to 390218...
# Uploading rows 390218 to 390717...
# Uploading rows 390717 to 391216...
# Uploading rows 391216 to 391715...
# Uploading rows 391715 to 392214...
# Uploading rows 392214 to 392713...
# Uploading rows 392713 to 393212...
# Uploading rows 393212 to 393711...
# Uploading rows 393711 to 394210...
# Uploading rows 394210 to 394709...
# Uploading rows 394709 to 395208...
# Uploading rows 395208 to 395707...
# Uploading rows 395707 to 396206...
# Uploading rows 396206 to 396705...
# Uploading rows 396705 to 397204...
# Uploading rows 397204 to 397703...
# Uploading rows 397703 to 398202...
# Uploading rows 398202 to 398701...
# Uploading rows 398701 to 399200...
# Uploading rows 399200 to 399699...
# Uploading rows 399699 to 400198...
# Uploading rows 400198 to 400697...
# Uploading rows 400697 to 401196...
# Uploading rows 401196 to 401695...
# Uploading rows 401695 to 402194...
# Uploading rows 402194 to 402693...
# Uploading rows 402693 to 403192...
# Uploading rows 403192 to 403691...
# Uploading rows 403691 to 404190...
# Uploading rows 404190 to 404689...
# Uploading rows 404689 to 405188...
# Uploading rows 405188 to 405687...
# Uploading rows 405687 to 406186...
# Uploading rows 406186 to 406685...
# Uploading rows 406685 to 407184...
# Uploading rows 407184 to 407683...
# Uploading rows 407683 to 408182...
# Uploading rows 408182 to 408681...
# Uploading rows 408681 to 409180...
# Uploading rows 409180 to 409679...
# Uploading rows 409679 to 410178...
# Uploading rows 410178 to 410677...
# Uploading rows 410677 to 411176...
# Uploading rows 411176 to 411675...
# Uploading rows 411675 to 412174...
# Uploading rows 412174 to 412673...
# Uploading rows 412673 to 413172...
# Uploading rows 413172 to 413671...
# Uploading rows 413671 to 414170...
# Uploading rows 414170 to 414669...
# Uploading rows 414669 to 415168...
# Uploading rows 415168 to 415667...
# Uploading rows 415667 to 416166...
# Uploading rows 416166 to 416665...
# Uploading rows 416665 to 417164...
# Uploading rows 417164 to 417663...
# Uploading rows 417663 to 418162...
# Uploading rows 418162 to 418661...
# Uploading rows 418661 to 419160...
# Uploading rows 419160 to 419659...
# Uploading rows 419659 to 420158...
# Uploading rows 420158 to 420657...
# Uploading rows 420657 to 421156...
# Uploading rows 421156 to 421655...
# Uploading rows 421655 to 422154...
# Uploading rows 422154 to 422653...
# Uploading rows 422653 to 423152...
# Uploading rows 423152 to 423651...
# Uploading rows 423651 to 424150...
# Uploading rows 424150 to 424649...
# Uploading rows 424649 to 425148...
# Uploading rows 425148 to 425647...
# Uploading rows 425647 to 426146...
# Uploading rows 426146 to 426645...
# Uploading rows 426645 to 427144...
# Uploading rows 427144 to 427643...
# Uploading rows 427643 to 428142...
# Uploading rows 428142 to 428641...
# Uploading rows 428641 to 429140...
# Uploading rows 429140 to 429639...
# Uploading rows 429639 to 430138...
# Uploading rows 430138 to 430637...
# Uploading rows 430637 to 431136...
# Uploading rows 431136 to 431635...
# Uploading rows 431635 to 432134...
# Uploading rows 432134 to 432633...
# Uploading rows 432633 to 433132...
# Uploading rows 433132 to 433631...
# Uploading rows 433631 to 434130...
# Uploading rows 434130 to 434629...
# Uploading rows 434629 to 435128...
# Uploading rows 435128 to 435627...
# Uploading rows 435627 to 436126...
# Uploading rows 436126 to 436625...
# Uploading rows 436625 to 437124...
# Uploading rows 437124 to 437623...
# Uploading rows 437623 to 438122...
# Uploading rows 438122 to 438621...
# Uploading rows 438621 to 439120...
# Uploading rows 439120 to 439619...
# Uploading rows 439619 to 440118...
# Uploading rows 440118 to 440617...
# Uploading rows 440617 to 441116...
# Uploading rows 441116 to 441615...
# Uploading rows 441615 to 442114...
# Uploading rows 442114 to 442613...
# Uploading rows 442613 to 443112...
# Uploading rows 443112 to 443611...
# Uploading rows 443611 to 444110...
# Uploading rows 444110 to 444609...
# Uploading rows 444609 to 445108...
# Uploading rows 445108 to 445607...
# Uploading rows 445607 to 446106...
# Uploading rows 446106 to 446605...
# Uploading rows 446605 to 447104...
# Uploading rows 447104 to 447603...
# Uploading rows 447603 to 448102...
# Uploading rows 448102 to 448601...
# Uploading rows 448601 to 449100...
# Uploading rows 449100 to 449599...
# Uploading rows 449599 to 450098...
# Uploading rows 450098 to 450597...
# Uploading rows 450597 to 451096...
# Uploading rows 451096 to 451595...
# Uploading rows 451595 to 452094...
# Uploading rows 452094 to 452593...
# Uploading rows 452593 to 453092...
# Uploading rows 453092 to 453591...
# Uploading rows 453591 to 454090...
# Uploading rows 454090 to 454589...
# Uploading rows 454589 to 455088...
# Uploading rows 455088 to 455587...
# Uploading rows 455587 to 456086...
# Uploading rows 456086 to 456585...
# Uploading rows 456585 to 457084...
# Uploading rows 457084 to 457583...
# Uploading rows 457583 to 458082...
# Uploading rows 458082 to 458581...
# Uploading rows 458581 to 459080...
# Uploading rows 459080 to 459579...
# Uploading rows 459579 to 460078...
# Uploading rows 460078 to 460577...
# Uploading rows 460577 to 461076...
# Uploading rows 461076 to 461575...
# Uploading rows 461575 to 462074...
# Uploading rows 462074 to 462573...
# Uploading rows 462573 to 463072...
# Uploading rows 463072 to 463571...
# Uploading rows 463571 to 464070...
# Uploading rows 464070 to 464569...
# Uploading rows 464569 to 465068...
# Uploading rows 465068 to 465567...
# Uploading rows 465567 to 466066...
# Uploading rows 466066 to 466565...
# Uploading rows 466565 to 467064...
# Uploading rows 467064 to 467563...
# Uploading rows 467563 to 468062...
# Uploading rows 468062 to 468561...
# Uploading rows 468561 to 469060...
# Uploading rows 469060 to 469559...
# Uploading rows 469559 to 470058...
# Uploading rows 470058 to 470557...
# Uploading rows 470557 to 471056...
# Uploading rows 471056 to 471555...
# Uploading rows 471555 to 472054...
# Uploading rows 472054 to 472553...
# Uploading rows 472553 to 473052...
# Uploading rows 473052 to 473551...
# Uploading rows 473551 to 474050...
# Uploading rows 474050 to 474549...
# Uploading rows 474549 to 475048...
# Uploading rows 475048 to 475547...
# Uploading rows 475547 to 476046...
# Uploading rows 476046 to 476545...
# Uploading rows 476545 to 477044...
# Uploading rows 477044 to 477543...
# Uploading rows 477543 to 478042...
# Uploading rows 478042 to 478541...
# Uploading rows 478541 to 479040...
# Uploading rows 479040 to 479539...
# Uploading rows 479539 to 480038...
# Uploading rows 480038 to 480537...
# Uploading rows 480537 to 481036...
# Uploading rows 481036 to 481535...
# Uploading rows 481535 to 482034...
# Uploading rows 482034 to 482533...
# Uploading rows 482533 to 483032...
# Uploading rows 483032 to 483531...
# Uploading rows 483531 to 484030...
# Uploading rows 484030 to 484529...
# Uploading rows 484529 to 485028...
# Uploading rows 485028 to 485527...
# Uploading rows 485527 to 486026...
# Uploading rows 486026 to 486525...
# Uploading rows 486525 to 487024...
# Uploading rows 487024 to 487523...
# Uploading rows 487523 to 488022...
# Uploading rows 488022 to 488521...
# Uploading rows 488521 to 489020...
# Uploading rows 489020 to 489519...
# Uploading rows 489519 to 490018...
# Uploading rows 490018 to 490517...
# Uploading rows 490517 to 491016...
# Uploading rows 491016 to 491515...
# Uploading rows 491515 to 492014...
# Uploading rows 492014 to 492513...
# Uploading rows 492513 to 493012...
# Uploading rows 493012 to 493511...
# Uploading rows 493511 to 494010...
# Uploading rows 494010 to 494509...
# Uploading rows 494509 to 495008...
# Uploading rows 495008 to 495507...
# Uploading rows 495507 to 496006...
# Uploading rows 496006 to 496505...
# Uploading rows 496505 to 497004...
# Uploading rows 497004 to 497503...
# Uploading rows 497503 to 498002...
# Uploading rows 498002 to 498501...
# Uploading rows 498501 to 499000...
# Uploading rows 499000 to 499499...
# Uploading rows 499499 to 499998...
# Uploading rows 499998 to 500497...
# Uploading rows 500497 to 500996...
# Uploading rows 500996 to 501495...
# Uploading rows 501495 to 501994...
# Uploading rows 501994 to 502493...
# Uploading rows 502493 to 502992...
# Uploading rows 502992 to 503491...
# Uploading rows 503491 to 503990...
# Uploading rows 503990 to 504489...
# Uploading rows 504489 to 504988...
# Uploading rows 504988 to 505487...
# Uploading rows 505487 to 505986...
# Uploading rows 505986 to 506485...
# Uploading rows 506485 to 506984...
# Uploading rows 506984 to 507483...
# Uploading rows 507483 to 507982...
# Uploading rows 507982 to 508481...
# Uploading rows 508481 to 508980...
# Uploading rows 508980 to 509479...
# Uploading rows 509479 to 509978...
# Uploading rows 509978 to 510477...
# Uploading rows 510477 to 510976...
# Uploading rows 510976 to 511475...
# Uploading rows 511475 to 511974...
# Uploading rows 511974 to 512473...
# Uploading rows 512473 to 512972...
# Uploading rows 512972 to 513471...
# Uploading rows 513471 to 513970...
# Uploading rows 513970 to 514469...
# Uploading rows 514469 to 514968...
# Uploading rows 514968 to 515467...
# Uploading rows 515467 to 515966...
# Uploading rows 515966 to 516465...
# Uploading rows 516465 to 516964...
# Uploading rows 516964 to 517463...
# Uploading rows 517463 to 517962...
# Uploading rows 517962 to 518461...
# Uploading rows 518461 to 518960...
# Uploading rows 518960 to 519459...
# Uploading rows 519459 to 519958...
# Uploading rows 519958 to 520457...
# Uploading rows 520457 to 520956...
# Uploading rows 520956 to 521455...
# Uploading rows 521455 to 521954...
# Uploading rows 521954 to 522453...
# Uploading rows 522453 to 522952...
# Uploading rows 522952 to 523451...
# Uploading rows 523451 to 523950...
# Uploading rows 523950 to 524449...
# Uploading rows 524449 to 524948...
# Uploading rows 524948 to 525447...
# Uploading rows 525447 to 525946...
# Uploading rows 525946 to 526445...
# Uploading rows 526445 to 526944...
# Uploading rows 526944 to 527443...
# Uploading rows 527443 to 527942...
# Uploading rows 527942 to 528441...
# Uploading rows 528441 to 528940...
# Uploading rows 528940 to 529439...
# Uploading rows 529439 to 529938...
# Uploading rows 529938 to 530437...
# Uploading rows 530437 to 530936...
# Uploading rows 530936 to 531435...
# Uploading rows 531435 to 531934...
# Uploading rows 531934 to 532433...
# Uploading rows 532433 to 532932...
# Uploading rows 532932 to 533431...
# Uploading rows 533431 to 533930...
# Uploading rows 533930 to 534429...
# Uploading rows 534429 to 534928...
# Uploading rows 534928 to 535427...
# Uploading rows 535427 to 535926...
# Uploading rows 535926 to 536425...
# Uploading rows 536425 to 536924...
# Uploading rows 536924 to 537423...
# Uploading rows 537423 to 537922...
# Uploading rows 537922 to 538421...
# Uploading rows 538421 to 538920...
# Uploading rows 538920 to 539419...
# Uploading rows 539419 to 539918...
# Uploading rows 539918 to 540417...
# Uploading rows 540417 to 540916...
# Uploading rows 540916 to 541415...
# Uploading rows 541415 to 541914...
# Uploading rows 541914 to 542413...
# Uploading rows 542413 to 542912...
# Uploading rows 542912 to 543411...
# Uploading rows 543411 to 543910...
# Uploading rows 543910 to 544409...
# Uploading rows 544409 to 544908...
# Uploading rows 544908 to 545407...
# Uploading rows 545407 to 545906...
# Uploading rows 545906 to 546405...
# Uploading rows 546405 to 546904...
# Uploading rows 546904 to 547403...
# Uploading rows 547403 to 547902...
# Uploading rows 547902 to 548401...
# Uploading rows 548401 to 548900...
# Uploading rows 548900 to 549399...
# Uploading rows 549399 to 549898...
# Uploading rows 549898 to 550397...
# Uploading rows 550397 to 550896...
# Uploading rows 550896 to 551395...
# Uploading rows 551395 to 551894...
# Uploading rows 551894 to 552393...
# Uploading rows 552393 to 552892...
# Uploading rows 552892 to 553391...
# Uploading rows 553391 to 553890...
# Uploading rows 553890 to 554389...
# Uploading rows 554389 to 554888...
# Uploading rows 554888 to 555387...
# Uploading rows 555387 to 555886...
# Uploading rows 555886 to 556385...
# Uploading rows 556385 to 556884...
# Uploading rows 556884 to 557383...
# Uploading rows 557383 to 557882...
# Uploading rows 557882 to 558381...
# Uploading rows 558381 to 558880...
# Uploading rows 558880 to 559379...
# Uploading rows 559379 to 559878...
# Uploading rows 559878 to 560377...
# Uploading rows 560377 to 560876...
# Uploading rows 560876 to 561375...
# Uploading rows 561375 to 561874...
# Uploading rows 561874 to 562373...
# Uploading rows 562373 to 562872...
# Uploading rows 562872 to 563371...
# Uploading rows 563371 to 563870...
# Uploading rows 563870 to 564369...
# Uploading rows 564369 to 564868...
# Uploading rows 564868 to 565367...
# Uploading rows 565367 to 565866...
# Uploading rows 565866 to 566365...
# Uploading rows 566365 to 566864...
# Uploading rows 566864 to 567363...
# Uploading rows 567363 to 567862...
# Uploading rows 567862 to 568361...
# Uploading rows 568361 to 568860...
# Uploading rows 568860 to 569359...
# Uploading rows 569359 to 569858...
# Uploading rows 569858 to 570357...
# Uploading rows 570357 to 570856...
# Uploading rows 570856 to 571355...
# Uploading rows 571355 to 571854...
# Uploading rows 571854 to 572353...
# Uploading rows 572353 to 572852...
# Uploading rows 572852 to 573351...
# Uploading rows 573351 to 573850...
# Uploading rows 573850 to 574349...
# Uploading rows 574349 to 574848...
# Uploading rows 574848 to 575347...
# Uploading rows 575347 to 575846...
# Uploading rows 575846 to 576345...
# Uploading rows 576345 to 576844...
# Uploading rows 576844 to 577343...
# Uploading rows 577343 to 577842...
# Uploading rows 577842 to 578341...
# Uploading rows 578341 to 578840...
# Uploading rows 578840 to 579339...
# Uploading rows 579339 to 579838...
# Uploading rows 579838 to 580337...
# Uploading rows 580337 to 580836...
# Uploading rows 580836 to 581335...
# Uploading rows 581335 to 581834...
# Uploading rows 581834 to 582333...
# Uploading rows 582333 to 582832...
# Uploading rows 582832 to 583331...
# Uploading rows 583331 to 583830...
# Uploading rows 583830 to 584329...
# Uploading rows 584329 to 584828...
# Uploading rows 584828 to 585327...
# Uploading rows 585327 to 585826...
# Uploading rows 585826 to 586325...
# Uploading rows 586325 to 586824...
# Uploading rows 586824 to 587323...
# Uploading rows 587323 to 587822...
# Uploading rows 587822 to 588321...
# Uploading rows 588321 to 588820...
# Uploading rows 588820 to 589319...
# Uploading rows 589319 to 589818...
# Uploading rows 589818 to 590317...
# Uploading rows 590317 to 590816...
# Uploading rows 590816 to 591315...
# Uploading rows 591315 to 591814...
# Uploading rows 591814 to 592313...
# Uploading rows 592313 to 592812...
# Uploading rows 592812 to 593311...
# Uploading rows 593311 to 593810...
# Uploading rows 593810 to 594309...
# Uploading rows 594309 to 594808...
# Uploading rows 594808 to 595307...
# Uploading rows 595307 to 595806...
# Uploading rows 595806 to 596305...
# Uploading rows 596305 to 596804...
# Uploading rows 596804 to 597303...
# Uploading rows 597303 to 597802...
# Uploading rows 597802 to 598301...
# Uploading rows 598301 to 598800...
# Uploading rows 598800 to 599299...
# Uploading rows 599299 to 599798...
# Uploading rows 599798 to 600297...
# Uploading rows 600297 to 600796...
# Uploading rows 600796 to 601295...
# Uploading rows 601295 to 601794...
# Uploading rows 601794 to 602293...
# Uploading rows 602293 to 602792...
# Uploading rows 602792 to 603291...
# Uploading rows 603291 to 603790...
# Uploading rows 603790 to 604289...
# Uploading rows 604289 to 604788...
# Uploading rows 604788 to 605287...
# Uploading rows 605287 to 605786...
# Uploading rows 605786 to 606285...
# Uploading rows 606285 to 606784...
# Uploading rows 606784 to 607283...
# Uploading rows 607283 to 607782...
# Uploading rows 607782 to 608281...
# Uploading rows 608281 to 608780...
# Uploading rows 608780 to 609279...
# Uploading rows 609279 to 609778...
# Uploading rows 609778 to 610277...
# Uploading rows 610277 to 610776...
# Uploading rows 610776 to 611275...
# Uploading rows 611275 to 611774...
# Uploading rows 611774 to 612273...
# Uploading rows 612273 to 612772...
# Uploading rows 612772 to 613271...
# Uploading rows 613271 to 613770...
# Uploading rows 613770 to 614269...
# Uploading rows 614269 to 614768...
# Uploading rows 614768 to 615267...
# Uploading rows 615267 to 615766...
# Uploading rows 615766 to 616265...
# Uploading rows 616265 to 616764...
# Uploading rows 616764 to 617263...
# Uploading rows 617263 to 617762...
# Uploading rows 617762 to 618261...
# Uploading rows 618261 to 618760...
# Uploading rows 618760 to 619259...
# Uploading rows 619259 to 619758...
# Uploading rows 619758 to 620257...
# Uploading rows 620257 to 620756...
# Uploading rows 620756 to 621255...
# Uploading rows 621255 to 621754...
# Uploading rows 621754 to 622253...
# Uploading rows 622253 to 622752...
# Uploading rows 622752 to 623251...
# Uploading rows 623251 to 623750...
# Uploading rows 623750 to 624249...
# Uploading rows 624249 to 624748...
# Uploading rows 624748 to 625247...
# Uploading rows 625247 to 625746...
# Uploading rows 625746 to 626245...
# Uploading rows 626245 to 626744...
# Uploading rows 626744 to 627243...
# Uploading rows 627243 to 627742...
# Uploading rows 627742 to 628241...
# Uploading rows 628241 to 628740...
# Uploading rows 628740 to 629239...
# Uploading rows 629239 to 629738...
# Uploading rows 629738 to 630237...
# Uploading rows 630237 to 630736...
# Uploading rows 630736 to 631235...
# Uploading rows 631235 to 631734...
# Uploading rows 631734 to 632233...
# Uploading rows 632233 to 632732...
# Uploading rows 632732 to 633231...
# Uploading rows 633231 to 633730...
# Uploading rows 633730 to 634229...
# Uploading rows 634229 to 634728...
# Uploading rows 634728 to 635227...
# Uploading rows 635227 to 635726...
# Uploading rows 635726 to 636225...
# Uploading rows 636225 to 636724...
# Uploading rows 636724 to 637223...
# Uploading rows 637223 to 637722...
# Uploading rows 637722 to 638221...
# Uploading rows 638221 to 638720...
# Uploading rows 638720 to 639219...
# Uploading rows 639219 to 639718...
# Uploading rows 639718 to 640217...
# Uploading rows 640217 to 640716...
# Uploading rows 640716 to 641215...
# Uploading rows 641215 to 641714...
# Uploading rows 641714 to 642213...
# Uploading rows 642213 to 642712...
# Uploading rows 642712 to 643211...
# Uploading rows 643211 to 643710...
# Uploading rows 643710 to 644209...
# Uploading rows 644209 to 644708...
# Uploading rows 644708 to 645207...
# Uploading rows 645207 to 645706...
# Uploading rows 645706 to 646205...
# Uploading rows 646205 to 646704...
# Uploading rows 646704 to 647203...
# Uploading rows 647203 to 647702...
# Uploading rows 647702 to 648201...
# Uploading rows 648201 to 648700...
# Uploading rows 648700 to 649199...
# Uploading rows 649199 to 649698...
# Uploading rows 649698 to 650197...
# Uploading rows 650197 to 650696...
# Uploading rows 650696 to 651195...
# Uploading rows 651195 to 651694...
# Uploading rows 651694 to 652193...
# Uploading rows 652193 to 652692...
# Uploading rows 652692 to 653191...
# Uploading rows 653191 to 653690...
# Uploading rows 653690 to 654189...
# Uploading rows 654189 to 654688...
# Uploading rows 654688 to 655187...
# Uploading rows 655187 to 655686...
# Uploading rows 655686 to 656185...
# Uploading rows 656185 to 656684...
# Uploading rows 656684 to 657183...
# Uploading rows 657183 to 657682...
# Uploading rows 657682 to 658181...
# Uploading rows 658181 to 658680...
# Uploading rows 658680 to 659179...
# Uploading rows 659179 to 659678...
# Uploading rows 659678 to 660177...
# Uploading rows 660177 to 660676...
# Uploading rows 660676 to 661175...
# Uploading rows 661175 to 661674...
# Uploading rows 661674 to 662173...
# Uploading rows 662173 to 662672...
# Uploading rows 662672 to 663171...
# Uploading rows 663171 to 663670...
# Uploading rows 663670 to 664169...
# Uploading rows 664169 to 664668...
# Uploading rows 664668 to 665167...
# Uploading rows 665167 to 665666...
# Uploading rows 665666 to 666165...
# Uploading rows 666165 to 666664...
# Uploading rows 666664 to 667163...
# Uploading rows 667163 to 667662...
# Uploading rows 667662 to 668161...
# Uploading rows 668161 to 668660...
# Uploading rows 668660 to 669159...
# Uploading rows 669159 to 669658...
# Uploading rows 669658 to 670157...
# Uploading rows 670157 to 670656...
# Uploading rows 670656 to 671155...
# Uploading rows 671155 to 671654...
# Uploading rows 671654 to 672153...
# Uploading rows 672153 to 672652...
# Uploading rows 672652 to 673151...
# Uploading rows 673151 to 673650...
# Uploading rows 673650 to 674149...
# Uploading rows 674149 to 674648...
# Uploading rows 674648 to 675147...
# Uploading rows 675147 to 675646...
# Uploading rows 675646 to 676145...
# Uploading rows 676145 to 676644...
# Uploading rows 676644 to 677143...
# Uploading rows 677143 to 677642...
# Uploading rows 677642 to 678141...
# Uploading rows 678141 to 678640...
# Uploading rows 678640 to 679139...
# Uploading rows 679139 to 679638...
# Uploading rows 679638 to 680137...
# Uploading rows 680137 to 680636...
# Uploading rows 680636 to 681135...
# Uploading rows 681135 to 681634...
# Uploading rows 681634 to 682133...
# Uploading rows 682133 to 682632...
# Uploading rows 682632 to 683131...
# Uploading rows 683131 to 683630...
# Uploading rows 683630 to 684129...
# Uploading rows 684129 to 684628...
# Uploading rows 684628 to 685127...
# Uploading rows 685127 to 685626...
# Uploading rows 685626 to 686125...
# Uploading rows 686125 to 686624...
# Uploading rows 686624 to 687123...
# Uploading rows 687123 to 687622...
# Uploading rows 687622 to 688121...
# Uploading rows 688121 to 688620...
# Uploading rows 688620 to 689119...
# Uploading rows 689119 to 689618...
# Uploading rows 689618 to 690117...
# ...
# Uploading rows 13286873 to 13287372...
# Uploading rows 13287372 to 13287871...
# Uploading rows 13287871 to 13288370...
# Uploading rows 13288370 to 13288869...
# Uploading rows 13288869 to 13289368...
# Uploading rows 13289368 to 13289867...
# Uploading rows 13289867 to 13290366...
# Uploading rows 13290366 to 13290865...
# Uploading rows 13290865 to 13291364...
# Uploading rows 13291364 to 13291863...
# Uploading rows 13291863 to 13292362...
# Uploading rows 13292362 to 13292861...
# Uploading rows 13292861 to 13293360...
# Uploading rows 13293360 to 13293859...
# Uploading rows 13293859 to 13294358...
# Uploading rows 13294358 to 13294857...
# Uploading rows 13294857 to 13295356...
# Uploading rows 13295356 to 13295855...
# Uploading rows 13295855 to 13296354...
# Uploading rows 13296354 to 13296853...
# Uploading rows 13296853 to 13297352...
# Uploading rows 13297352 to 13297851...
# Uploading rows 13297851 to 13298350...
# Uploading rows 13298350 to 13298849...
# Uploading rows 13298849 to 13299348...
# Uploading rows 13299348 to 13299847...
# Uploading rows 13299847 to 13300346...
# Uploading rows 13300346 to 13300845...
# Uploading rows 13300845 to 13301344...
# Uploading rows 13301344 to 13301843...
# Uploading rows 13301843 to 13302342...
# Uploading rows 13302342 to 13302841...
# Uploading rows 13302841 to 13303340...
# Uploading rows 13303340 to 13303839...
# Uploading rows 13303839 to 13304338...
# Uploading rows 13304338 to 13304837...
# Uploading rows 13304837 to 13305336...
# Uploading rows 13305336 to 13305835...
# Uploading rows 13305835 to 13306334...
# Uploading rows 13306334 to 13306833...
# Uploading rows 13306833 to 13307332...
# Uploading rows 13307332 to 13307831...
# Uploading rows 13307831 to 13308330...
# Uploading rows 13308330 to 13308829...
# Uploading rows 13308829 to 13309328...
# Uploading rows 13309328 to 13309827...
# Uploading rows 13309827 to 13310326...
# Uploading rows 13310326 to 13310825...
# Uploading rows 13310825 to 13311324...
# Uploading rows 13311324 to 13311823...
# Uploading rows 13311823 to 13312322...
# Uploading rows 13312322 to 13312821...
# Uploading rows 13312821 to 13313320...
# Uploading rows 13313320 to 13313819...
# Uploading rows 13313819 to 13314318...
# Uploading rows 13314318 to 13314817...
# Uploading rows 13314817 to 13315316...
# Uploading rows 13315316 to 13315815...
# Uploading rows 13315815 to 13316314...
# Uploading rows 13316314 to 13316813...
# Uploading rows 13316813 to 13317312...
# Uploading rows 13317312 to 13317811...
# Uploading rows 13317811 to 13318310...
# Uploading rows 13318310 to 13318809...
# Uploading rows 13318809 to 13319308...
# Uploading rows 13319308 to 13319807...
# Uploading rows 13319807 to 13320306...
# Uploading rows 13320306 to 13320805...
# Uploading rows 13320805 to 13321304...
# Uploading rows 13321304 to 13321803...
# Uploading rows 13321803 to 13322302...
# Uploading rows 13322302 to 13322801...
# Uploading rows 13322801 to 13323300...
# Uploading rows 13323300 to 13323799...
# Uploading rows 13323799 to 13324298...
# Uploading rows 13324298 to 13324797...
# Uploading rows 13324797 to 13325296...
# Uploading rows 13325296 to 13325795...
# Uploading rows 13325795 to 13326294...
# Uploading rows 13326294 to 13326793...
# Uploading rows 13326793 to 13327292...
# Uploading rows 13327292 to 13327791...
# Uploading rows 13327791 to 13328290...
# Uploading rows 13328290 to 13328789...
# Uploading rows 13328789 to 13329288...
# Uploading rows 13329288 to 13329787...
# Uploading rows 13329787 to 13330286...
# Uploading rows 13330286 to 13330785...
# Uploading rows 13330785 to 13331284...
# Uploading rows 13331284 to 13331783...
# Uploading rows 13331783 to 13332282...
# Uploading rows 13332282 to 13332781...
# Uploading rows 13332781 to 13333280...
# Uploading rows 13333280 to 13333779...
# Uploading rows 13333779 to 13334278...
# Uploading rows 13334278 to 13334777...
# Uploading rows 13334777 to 13335276...
# Uploading rows 13335276 to 13335775...
# Uploading rows 13335775 to 13336274...
# Uploading rows 13336274 to 13336773...
# Uploading rows 13336773 to 13337272...
# Uploading rows 13337272 to 13337771...
# Uploading rows 13337771 to 13338270...
# Uploading rows 13338270 to 13338769...
# Uploading rows 13338769 to 13339268...
# Uploading rows 13339268 to 13339767...
# Uploading rows 13339767 to 13340266...
# Uploading rows 13340266 to 13340765...
# Uploading rows 13340765 to 13341264...
# Uploading rows 13341264 to 13341763...
# Uploading rows 13341763 to 13342262...
# Uploading rows 13342262 to 13342761...
# Uploading rows 13342761 to 13343260...
# Uploading rows 13343260 to 13343759...
# Uploading rows 13343759 to 13344258...
# Uploading rows 13344258 to 13344757...
# Uploading rows 13344757 to 13345256...
# Uploading rows 13345256 to 13345755...
# Uploading rows 13345755 to 13346254...
# Uploading rows 13346254 to 13346753...
# Uploading rows 13346753 to 13347252...
# Uploading rows 13347252 to 13347751...
# Uploading rows 13347751 to 13348250...
# Uploading rows 13348250 to 13348749...
# Uploading rows 13348749 to 13349248...
# Uploading rows 13349248 to 13349747...
# Uploading rows 13349747 to 13350246...
# Uploading rows 13350246 to 13350745...
# Uploading rows 13350745 to 13351244...
# Uploading rows 13351244 to 13351743...
# Uploading rows 13351743 to 13352242...
# Uploading rows 13352242 to 13352741...
# Uploading rows 13352741 to 13353240...
# Uploading rows 13353240 to 13353739...
# Uploading rows 13353739 to 13354238...
# Uploading rows 13354238 to 13354737...
# Uploading rows 13354737 to 13355236...
# Uploading rows 13355236 to 13355735...
# Uploading rows 13355735 to 13356234...
# Uploading rows 13356234 to 13356733...
# Uploading rows 13356733 to 13357232...
# Uploading rows 13357232 to 13357731...
# Uploading rows 13357731 to 13358230...
# Uploading rows 13358230 to 13358729...
# Uploading rows 13358729 to 13359228...
# Uploading rows 13359228 to 13359727...
# Uploading rows 13359727 to 13360226...
# Uploading rows 13360226 to 13360725...
# Uploading rows 13360725 to 13361224...
# Uploading rows 13361224 to 13361723...
# Uploading rows 13361723 to 13362222...
# Uploading rows 13362222 to 13362721...
# Uploading rows 13362721 to 13363220...
# Uploading rows 13363220 to 13363719...
# Uploading rows 13363719 to 13364218...
# Uploading rows 13364218 to 13364717...
# Uploading rows 13364717 to 13365216...
# Uploading rows 13365216 to 13365715...
# Uploading rows 13365715 to 13366214...
# Uploading rows 13366214 to 13366713...
# Uploading rows 13366713 to 13367212...
# Uploading rows 13367212 to 13367711...
# Uploading rows 13367711 to 13368210...
# Uploading rows 13368210 to 13368709...
# Uploading rows 13368709 to 13369208...
# Uploading rows 13369208 to 13369707...
# Uploading rows 13369707 to 13370206...
# Uploading rows 13370206 to 13370705...
# Uploading rows 13370705 to 13371204...
# Uploading rows 13371204 to 13371703...
# Uploading rows 13371703 to 13372202...
# Uploading rows 13372202 to 13372701...
# Uploading rows 13372701 to 13373200...
# Uploading rows 13373200 to 13373699...
# Uploading rows 13373699 to 13374198...
# Uploading rows 13374198 to 13374697...
# Uploading rows 13374697 to 13375196...
# Uploading rows 13375196 to 13375695...
# Uploading rows 13375695 to 13376194...
# Uploading rows 13376194 to 13376693...
# Uploading rows 13376693 to 13377192...
# Uploading rows 13377192 to 13377691...
# Uploading rows 13377691 to 13378190...
# Uploading rows 13378190 to 13378689...
# Uploading rows 13378689 to 13379188...
# Uploading rows 13379188 to 13379687...
# Uploading rows 13379687 to 13380186...
# Uploading rows 13380186 to 13380685...
# Uploading rows 13380685 to 13381184...
# Uploading rows 13381184 to 13381683...
# Uploading rows 13381683 to 13382182...
# Uploading rows 13382182 to 13382681...
# Uploading rows 13382681 to 13383180...
# Uploading rows 13383180 to 13383679...
# Uploading rows 13383679 to 13384178...
# Uploading rows 13384178 to 13384677...
# Uploading rows 13384677 to 13385176...
# Uploading rows 13385176 to 13385675...
# Uploading rows 13385675 to 13386174...
# Uploading rows 13386174 to 13386673...
# Uploading rows 13386673 to 13387172...
# Uploading rows 13387172 to 13387671...
# Uploading rows 13387671 to 13388170...
# Uploading rows 13388170 to 13388669...
# Uploading rows 13388669 to 13389168...
# Uploading rows 13389168 to 13389667...
# Uploading rows 13389667 to 13390166...
# Uploading rows 13390166 to 13390665...
# Uploading rows 13390665 to 13391164...
# Uploading rows 13391164 to 13391663...
# Uploading rows 13391663 to 13392162...
# Uploading rows 13392162 to 13392661...
# Uploading rows 13392661 to 13393160...
# Uploading rows 13393160 to 13393659...
# Uploading rows 13393659 to 13394158...
# Uploading rows 13394158 to 13394657...
# Uploading rows 13394657 to 13395156...
# Uploading rows 13395156 to 13395655...
# Uploading rows 13395655 to 13396154...
# Uploading rows 13396154 to 13396653...
# Uploading rows 13396653 to 13397152...
# Uploading rows 13397152 to 13397651...
# Uploading rows 13397651 to 13398150...
# Uploading rows 13398150 to 13398649...
# Uploading rows 13398649 to 13399148...
# Uploading rows 13399148 to 13399647...
# Uploading rows 13399647 to 13400146...
# Uploading rows 13400146 to 13400645...
# Uploading rows 13400645 to 13401144...
# Uploading rows 13401144 to 13401643...
# Uploading rows 13401643 to 13402142...
# Uploading rows 13402142 to 13402641...
# Uploading rows 13402641 to 13403140...
# Uploading rows 13403140 to 13403639...
# Uploading rows 13403639 to 13404138...
# Uploading rows 13404138 to 13404637...
# Uploading rows 13404637 to 13405136...
# Uploading rows 13405136 to 13405635...
# Uploading rows 13405635 to 13406134...
# Uploading rows 13406134 to 13406633...
# Uploading rows 13406633 to 13407132...
# Uploading rows 13407132 to 13407631...
# Uploading rows 13407631 to 13408130...
# Uploading rows 13408130 to 13408629...
# Uploading rows 13408629 to 13409128...
# Uploading rows 13409128 to 13409627...
# Uploading rows 13409627 to 13410126...
# Uploading rows 13410126 to 13410625...
# Uploading rows 13410625 to 13411124...
# Uploading rows 13411124 to 13411623...
# Uploading rows 13411623 to 13412122...
# Uploading rows 13412122 to 13412621...
# Uploading rows 13412621 to 13413120...
# Uploading rows 13413120 to 13413619...
# Uploading rows 13413619 to 13414118...
# Uploading rows 13414118 to 13414617...
# Uploading rows 13414617 to 13415116...
# Uploading rows 13415116 to 13415615...
# Uploading rows 13415615 to 13416114...
# Uploading rows 13416114 to 13416613...
# Uploading rows 13416613 to 13417112...
# Uploading rows 13417112 to 13417611...
# Uploading rows 13417611 to 13418110...
# Uploading rows 13418110 to 13418609...
# Uploading rows 13418609 to 13419108...
# Uploading rows 13419108 to 13419607...
# Uploading rows 13419607 to 13420106...
# Uploading rows 13420106 to 13420605...
# Uploading rows 13420605 to 13421104...
# Uploading rows 13421104 to 13421603...
# Uploading rows 13421603 to 13422102...
# Uploading rows 13422102 to 13422601...
# Uploading rows 13422601 to 13423100...
# Uploading rows 13423100 to 13423599...
# Uploading rows 13423599 to 13424098...
# Uploading rows 13424098 to 13424597...
# Uploading rows 13424597 to 13425096...
# Uploading rows 13425096 to 13425595...
# Uploading rows 13425595 to 13426094...
# Uploading rows 13426094 to 13426593...
# Uploading rows 13426593 to 13427092...
# Uploading rows 13427092 to 13427591...
# Uploading rows 13427591 to 13428090...
# Uploading rows 13428090 to 13428589...
# Uploading rows 13428589 to 13429088...
# Uploading rows 13429088 to 13429587...
# Uploading rows 13429587 to 13430086...
# Uploading rows 13430086 to 13430585...
# Uploading rows 13430585 to 13431084...
# Uploading rows 13431084 to 13431583...
# Uploading rows 13431583 to 13432082...
# Uploading rows 13432082 to 13432581...
# Uploading rows 13432581 to 13433080...
# Uploading rows 13433080 to 13433579...
# Uploading rows 13433579 to 13434078...
# Uploading rows 13434078 to 13434577...
# Uploading rows 13434577 to 13435076...
# Uploading rows 13435076 to 13435575...
# Uploading rows 13435575 to 13436074...
# Uploading rows 13436074 to 13436573...
# Uploading rows 13436573 to 13437072...
# Uploading rows 13437072 to 13437571...
# Uploading rows 13437571 to 13438070...
# Uploading rows 13438070 to 13438569...
# Uploading rows 13438569 to 13439068...
# Uploading rows 13439068 to 13439567...
# Uploading rows 13439567 to 13440066...
# Uploading rows 13440066 to 13440565...
# Uploading rows 13440565 to 13441064...
# Uploading rows 13441064 to 13441563...
# Uploading rows 13441563 to 13442062...
# Uploading rows 13442062 to 13442561...
# Uploading rows 13442561 to 13443060...
# Uploading rows 13443060 to 13443559...
# Uploading rows 13443559 to 13444058...
# Uploading rows 13444058 to 13444557...
# Uploading rows 13444557 to 13445056...
# Uploading rows 13445056 to 13445555...
# Uploading rows 13445555 to 13446054...
# Uploading rows 13446054 to 13446553...
# Uploading rows 13446553 to 13447052...
# Uploading rows 13447052 to 13447551...
# Uploading rows 13447551 to 13448050...
# Uploading rows 13448050 to 13448549...
# Uploading rows 13448549 to 13449048...
# Uploading rows 13449048 to 13449547...
# Uploading rows 13449547 to 13450046...
# Uploading rows 13450046 to 13450545...
# Uploading rows 13450545 to 13451044...
# Uploading rows 13451044 to 13451543...
# Uploading rows 13451543 to 13452042...
# Uploading rows 13452042 to 13452541...
# Uploading rows 13452541 to 13453040...
# Uploading rows 13453040 to 13453539...
# Uploading rows 13453539 to 13454038...
# Uploading rows 13454038 to 13454537...
# Uploading rows 13454537 to 13455036...
# Uploading rows 13455036 to 13455535...
# Uploading rows 13455535 to 13456034...
# Uploading rows 13456034 to 13456533...
# Uploading rows 13456533 to 13457032...
# Uploading rows 13457032 to 13457531...
# Uploading rows 13457531 to 13458030...
# Uploading rows 13458030 to 13458529...
# Uploading rows 13458529 to 13459028...
# Uploading rows 13459028 to 13459527...
# Uploading rows 13459527 to 13460026...
# Uploading rows 13460026 to 13460525...
# Uploading rows 13460525 to 13461024...
# Uploading rows 13461024 to 13461523...
# Uploading rows 13461523 to 13462022...
# Uploading rows 13462022 to 13462521...
# Uploading rows 13462521 to 13463020...
# Uploading rows 13463020 to 13463519...
# Uploading rows 13463519 to 13464018...
# Uploading rows 13464018 to 13464517...
# Uploading rows 13464517 to 13465016...
# Uploading rows 13465016 to 13465515...
# Uploading rows 13465515 to 13466014...
# Uploading rows 13466014 to 13466513...
# Uploading rows 13466513 to 13467012...
# Uploading rows 13467012 to 13467511...
# Uploading rows 13467511 to 13468010...
# Uploading rows 13468010 to 13468509...
# Uploading rows 13468509 to 13469008...
# Uploading rows 13469008 to 13469507...
# Uploading rows 13469507 to 13470006...
# Uploading rows 13470006 to 13470505...
# Uploading rows 13470505 to 13471004...
# Uploading rows 13471004 to 13471503...
# Uploading rows 13471503 to 13472002...
# Uploading rows 13472002 to 13472501...
# Uploading rows 13472501 to 13473000...
# Uploading rows 13473000 to 13473499...
# Uploading rows 13473499 to 13473998...
# Uploading rows 13473998 to 13474497...
# Uploading rows 13474497 to 13474996...
# Uploading rows 13474996 to 13475495...
# Uploading rows 13475495 to 13475994...
# Uploading rows 13475994 to 13476493...
# Uploading rows 13476493 to 13476992...
# Uploading rows 13476992 to 13477491...
# Uploading rows 13477491 to 13477990...
# Uploading rows 13477990 to 13478489...
# Uploading rows 13478489 to 13478988...
# Uploading rows 13478988 to 13479487...
# Uploading rows 13479487 to 13479986...
# Uploading rows 13479986 to 13480485...
# Uploading rows 13480485 to 13480984...
# Uploading rows 13480984 to 13481483...
# Uploading rows 13481483 to 13481982...
# Uploading rows 13481982 to 13482481...
# Uploading rows 13482481 to 13482980...
# Uploading rows 13482980 to 13483479...
# Uploading rows 13483479 to 13483978...
# Uploading rows 13483978 to 13484477...
# Uploading rows 13484477 to 13484976...
# Uploading rows 13484976 to 13485475...
# Uploading rows 13485475 to 13485974...
# Uploading rows 13485974 to 13486473...
# Uploading rows 13486473 to 13486972...
# Uploading rows 13486972 to 13487471...
# Uploading rows 13487471 to 13487970...
# Uploading rows 13487970 to 13488469...
# Uploading rows 13488469 to 13488968...
# Uploading rows 13488968 to 13489467...
# Uploading rows 13489467 to 13489966...
# Uploading rows 13489966 to 13490465...
# Uploading rows 13490465 to 13490604...
# Data upload complete!

# %% [markdown]
# #

# %% [markdown]
# #### Let's perform a few queries to test the connection and that everything has been uploaded properly.
# #### We will limit the query replies in order to avoid potential issues emerging from the vast data volume on Firestore.

# %%
# Test Firestore connection by fetching the first document of the collection
# We can verify the accuracy of the answer by simultaneously checking the firestore documents from the cloud
collection_name = "crime_data"
query = db.collection(collection_name).limit(1).stream()

for doc in query:
    print(f"Document ID: {doc.id}, Data: {doc.to_dict()}")
# Out:
# Document ID: 0000pqVKxcVDaXRNeOap, Data: {'major_category': 'Criminal Damage', 'year': 2009, 'value': 0, 'lsoa_code': 'E01001111', 'borough': 'Croydon', 'month': 3, 'minor_category': 'Criminal Damage To Other Building'}

# %%
# Count total documents in the collection
# We limit this query to the first 100.000 documents to avoid computational power issues
collection_name = "crime_data"
docs = db.collection(collection_name).limit(100000).stream()
doc_count = sum(1 for _ in docs)
print(f"Total documents in '{collection_name}': {doc_count}")
# Out:
# Total documents in 'crime_data': 100000

# %%
# Query for a specific borough
# Again this is limited to the first 10 entries for simplicity reasons
borough = "Croydon"
query = db.collection(collection_name).where("borough", "==", borough).limit(10).stream()

print(f"Crime records for borough '{borough}':")
for doc in query:
    print(f"Document ID: {doc.id}, Data: {doc.to_dict()}")
# Out:
# Crime records for borough 'Croydon':
# Document ID: 0000pqVKxcVDaXRNeOap, Data: {'major_category': 'Criminal Damage', 'year': 2009, 'value': 0, 'lsoa_code': 'E01001111', 'borough': 'Croydon', 'month': 3, 'minor_category': 'Criminal Damage To Other Building'}
# Document ID: 000AWa1pptq1ZvATBsPM, Data: {'major_category': 'Theft and Handling', 'year': 2015, 'value': 0, 'lsoa_code': 'E01001138', 'borough': 'Croydon', 'month': 11, 'minor_category': 'Handling Stolen Goods'}
# Document ID: 000DZCX3lSJXiYy4hyhA, Data: {'major_category': 'Robbery', 'year': 2015, 'value': 0, 'lsoa_code': 'E01000997', 'borough': 'Croydon', 'month': 7, 'minor_category': 'Personal Property'}
# Document ID: 000sSzwjQB2BuTKS1wDR, Data: {'major_category': 'Theft and Handling', 'year': 2010, 'value': 2, 'lsoa_code': 'E01001125', 'borough': 'Croydon', 'month': 8, 'minor_category': 'Theft From Shops'}
# Document ID: 0016uKFb4oAPegGKv79O, Data: {'major_category': 'Criminal Damage', 'year': 2016, 'value': 0, 'lsoa_code': 'E01000995', 'borough': 'Croydon', 'month': 10, 'minor_category': 'Other Criminal Damage'}
# Document ID: 001PFsv6qG6yFqv0v7bq, Data: {'major_category': 'Theft and Handling', 'year': 2012, 'value': 0, 'lsoa_code': 'E01001115', 'borough': 'Croydon', 'month': 1, 'minor_category': 'Motor Vehicle Interference & Tampering'}
# Document ID: 001kP0whKZgJKz20fuGG, Data: {'major_category': 'Theft and Handling', 'year': 2011, 'value': 0, 'lsoa_code': 'E01001194', 'borough': 'Croydon', 'month': 11, 'minor_category': 'Handling Stolen Goods'}
# Document ID: 001oB3nrzMiLpXu3iVdM, Data: {'major_category': 'Burglary', 'year': 2008, 'value': 1, 'lsoa_code': 'E01000982', 'borough': 'Croydon', 'month': 3, 'minor_category': 'Burglary in a Dwelling'}
# Document ID: 0023wnoJQw61TyE0fU9l, Data: {'major_category': 'Violence Against the Person', 'year': 2011, 'value': 1, 'lsoa_code': 'E01000990', 'borough': 'Croydon', 'month': 12, 'minor_category': 'Common Assault'}
# Document ID: 002k00WV7Ex7ck7r7PKs, Data: {'major_category': 'Violence Against the Person', 'year': 2010, 'value': 1, 'lsoa_code': 'E01001185', 'borough': 'Croydon', 'month': 3, 'minor_category': 'Assault with Injury'}

# %% [markdown]
# #

# %% [markdown]
# #### Queries in Firestore are working fine, but we will use a different approach to continue from now on.
# #### To end this notebook, we transform the dataset to JSON format, for uploading to a Dataproc bucket and continuing from there.

# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder \
    .appName("CSVtoJSON") \
    .master("local[*]") \
    .getOrCreate()

# %%
# Path to our CSV file
csv_file_path = "london_crime.csv"  

# Load the CSV file
df = spark.read.csv(csv_file_path, header=True, inferSchema=True)

# Show the first few rows of the DataFrame
df.show()
# Out:
# +---------+--------------------+--------------------+--------------------+-----+----+-----+
# |lsoa_code|             borough|      major_category|      minor_category|value|year|month|
# +---------+--------------------+--------------------+--------------------+-----+----+-----+
# |E01001116|             Croydon|            Burglary|Burglary in Other...|    0|2016|   11|
# |E01001646|           Greenwich|Violence Against ...|      Other violence|    0|2016|   11|
# |E01000677|             Bromley|Violence Against ...|      Other violence|    0|2015|    5|
# |E01003774|           Redbridge|            Burglary|Burglary in Other...|    0|2016|    3|
# |E01004563|          Wandsworth|             Robbery|   Personal Property|    0|2008|    6|
# |E01001320|              Ealing|  Theft and Handling|         Other Theft|    0|2012|    5|
# |E01001342|              Ealing|Violence Against ...|    Offensive Weapon|    0|2010|    7|
# |E01002633|            Hounslow|             Robbery|   Personal Property|    0|2013|    4|
# |E01003496|              Newham|     Criminal Damage|Criminal Damage T...|    0|2013|    9|
# |E01004177|              Sutton|  Theft and Handling|Theft/Taking of P...|    1|2016|    8|
# |E01001985|            Haringey|  Theft and Handling|Motor Vehicle Int...|    0|2013|   12|
# |E01003076|             Lambeth|Violence Against ...|      Other violence|    0|2015|    4|
# |E01003852|Richmond upon Thames|             Robbery|   Personal Property|    0|2014|    1|
# |E01004547|          Wandsworth|Violence Against ...|    Offensive Weapon|    0|2011|   10|
# |E01002398|          Hillingdon|  Theft and Handling|Theft/Taking Of M...|    0|2016|    2|
# |E01002358|            Havering|Violence Against ...|        Wounding/GBH|    0|2012|    2|
# |E01000086|Barking and Dagenham|  Theft and Handling|  Other Theft Person|    1|2009|    5|
# |E01003708|           Redbridge|Violence Against ...|      Common Assault|    0|2009|    6|
# |E01002945|Kingston upon Thames|  Theft and Handling|    Theft From Shops|    0|2016|   11|
# |E01004195|              Sutton|               Drugs| Possession Of Drugs|    0|2009|   10|
# +---------+--------------------+--------------------+--------------------+-----+----+-----+
# only showing top 20 rows

# %%
# Path to save the JSON file
json_file_path = "london_crime_json.json" 

# Save as JSON
df.write.json(json_file_path)

print(f"JSON file saved at {json_file_path}")
# Out:
# JSON file saved at london_crime_json.json
